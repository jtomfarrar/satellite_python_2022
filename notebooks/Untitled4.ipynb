# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
pi = math.pi
rho = 1.68*10**-8
l = 0.12 
a = pi/4*(0.00635 - 0.00473)**2
s = rho*(l/a)
p = 1480

# %%
def f(x, y):
    return np.x*(math.sqrt(p/(s+(x*y))))/x

x = np.linspace(1, 15, 30)
y = np.linspace(0.025, 0.25, 30)

X, Y = np.meshgrid(x, y)
#Z = f(X,Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z)

# %%
math.sqrt(25)
# Out:
# 5.0

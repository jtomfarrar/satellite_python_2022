# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

import cartopy.crs as ccrs                   # import projections
import cartopy
import gsw
# import cftime

# %%
# %matplotlib inline
# %matplotlib qt5

plt.rcParams['figure.figsize'] = (5,4)
plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 400
plt.close('all')

__figdir__ = '../plots/' + 'SMODE_'
savefig_args = {'bbox_inches':'tight', 'pad_inches':0.2}
plotfiletype='png'

# To save the plotted image
savefig = 1

# %%
file = r"..\Data\IFREMER-GLOB-SST-L3-NRT-OBS_FULL_TIME_SERIE_1641567446094.nc"

# %%
ds = xr.open_dataset(file)             #dataset

# %%
ds                         #open the dataset
# Out:
# <xarray.Dataset>
# Dimensions:                              (lat: 1600, lon: 3600, time: 1)
# Coordinates:
#   * time                                 (time) datetime64[ns] 2022-01-06
#   * lat                                  (lat) float32 -79.95 -79.85 ... 79.95
#   * lon                                  (lon) float32 -179.9 -179.9 ... 179.9
# Data variables:
#     adjusted_sea_surface_temperature     (time, lat, lon) float32 ...
#     sses_standard_deviation              (time, lat, lon) float32 ...
#     or_latitude                          (time, lat, lon) float32 ...
#     standard_deviation_to_reference_sst  (time, lat, lon) float32 ...
#     bias_to_reference_sst                (time, lat, lon) float32 ...
#     sea_surface_temperature              (time, lat, lon) float32 ...
#     sses_bias                            (time, lat, lon) float32 ...
#     sst_dtime                            (time, lat, lon) timedelta64[ns] ...
#     or_number_of_pixels                  (time, lat, lon) float32 ...
#     solar_zenith_angle                   (time, lat, lon) float32 ...
#     quality_level                        (time, lat, lon) float32 ...
#     satellite_zenith_angle               (time, lat, lon) float32 ...
#     adjusted_standard_deviation_error    (time, lat, lon) float32 ...
#     sources_of_sst                       (time, lat, lon) float32 ...
#     or_longitude                         (time, lat, lon) float32 ...
# Attributes:
#     Conventions:                     CF-1.7, ACDD-1.3, ISO 8601
#     standard_name_vocabulary:        NCDF Climate and Forecast (CF) Metadata ...
#     naming_authority:                org.ghrsst
#     netcdf_version_id:               4.6.1 of Sep  8 2018 17:21:01 $
#     title:                           Merged collation of sea surface temperat...
#     id:                              IFR-L3S-GLOB-ODYSSEA
#     cmems_product_id:                SST_GLO_SST_L3S_NRT_OBSERVATIONS_010_010
#     summary:                         Multi-sensor composite on a 0.1 degree r...
#     references:                      Product User Manual for Level 3 and 4 OD...
#     metadata_link:
#     processing_level:                L3S
#     keywords:                        Oceans > Ocean Temperature > Sea Surface...
#     keywords_vocabulary:             NASA Global Change Master Directory (GCM...
#     project:                         Copernicus - Marine environment monitori...
#     program:                         GHRSST, CMEMS
#     institution:                     Institut Francais de Recherche pour l'Ex...
#     institution_abbreviation:        Ifremer/Cersat
#     license:                         These data are available free of charge ...
#     acknowledgment:                  Please acknowledge the use of these data...
#     contact:                         jean.francois.piolle@ifremer.fr;emmanuel...
#     technical_support_contact:       cersat@ifremer.fr
#     scientific_support_contact:      emmanuelle.autret@ifremer.fr;jfpiolle@if...
#     creator_email:                   cersat@ifremer.fr
#     creator_type:                    institution
#     creator_institution:             Ifremer / CERSAT
#     creator_name:                    CERSAT
#     creator_url:                     http://cersat.ifremer.fr
#     publisher_email:                 servicedesk.cmems@mercator-ocean.eu
#     publisher_institution:           CMEMS
#     publisher_name:                  CMEMS
#     publisher_url:                   marine.copernicus.eu
#     format_version:                  GHRSST GDS v2.1
#     gds_version_id:                  2.1
#     processing_software:             Odyssea 3.0
#     source:                          Odyssea L4 Processor
#     source_version:                  2.0
#     geospatial_bounds:               POLYGON ((-180.0 -80.0, 180.0 -80.0, 180...
#     geospatial_bounds_crs:           WGS84
#     geospatial_bounds_vertical_crs:  EPSG:5831
#     geospatial_lat_max:              79.94999694824219
#     geospatial_lat_min:              -79.94999694824219
#     geospatial_lat_resolution:       0.1
#     geospatial_lat_units:            degrees_north
#     geospatial_lon_max:              179.9499969482422
#     geospatial_lon_min:              -179.9499969482422
#     geospatial_lon_resolution:       0.1
#     geospatial_lon_units:            degrees_east
#     time_coverage_end:               2022-01-06T12:00:00
#     time_coverage_resolution:        P1D
#     time_coverage_start:             2022-01-05T12:00:00
#     spatial_resolution:              0.1 degree
#     temporal_resolution:             daily
#     cdm_data_type:                   grid
#     source_data:                     AVHRR_SST_METOP_B-OSISAF-L2P-v1.0 SLSTRA...
#     platform:                        Metop-B;Sentinel-3A;Sentinel-3B;NOAA-20;...
#     platform_type:                   low_earth_orbit_satellite low_earth_orbi...
#     platform_vocabulary:             CEOS
#     instrument:                      AVHRR/3 SLSTR SLSTR VIIRS VIIRS ABI ABI ...
#     instrument_type:                 infrared_radiometer infrared_radiometer ...
#     instrument_vocabulary:           CEOS
#     product_version:                 1.0
#     date_created:                    2022-01-06T10:28:01
#     date_modified:                   2022-01-07T12:00:19
#     date_issued:                     2022-01-07T12:00:19
#     date_metadata_modified:          2019-02-01T00:00:00
#     history:                         collated data file originally produced b...
#     uuid:                            e721794d-584b-459e-927f-69c9542180ff
#     file_quality_level:              3
#     comment:                         WARNING:Some applications are unable to ...
#     History:                         Translated to CF-1.0 Conventions by Netc...

# %%
ds.lat
# Out:
# <xarray.DataArray 'lat' (lat: 1600)>
# array([-79.95, -79.85, -79.75, ...,  79.75,  79.85,  79.95], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 -79.95 -79.85 -79.75 -79.65 ... 79.75 79.85 79.95
# Attributes:
#     long_name:            latitude
#     units:                degrees_north
#     standard_name:        latitude
#     axis:                 Y
#     _ChunkSizes:          1600
#     _CoordinateAxisType:  Lat

# %%
ds.lon
# Out:
# <xarray.DataArray 'lon' (lon: 3600)>
# array([-179.95, -179.85, -179.75, ...,  179.75,  179.85,  179.95],
#       dtype=float32)
# Coordinates:
#   * lon      (lon) float32 -179.9 -179.9 -179.8 -179.6 ... 179.8 179.9 179.9
# Attributes:
#     standard_name:        longitude
#     axis:                 X
#     long_name:            longitude
#     units:                degrees_east
#     _ChunkSizes:          3600
#     _CoordinateAxisType:  Lon

# %%
sst = ds.sea_surface_temperature -273.15

# %%
fig = plt.figure()
ax = plt.axes(projection = ccrs.PlateCarree(central_longitude=200))  # Orthographic
ax.set_title('Sea Surface Temperature')

# Set plot axes two different ways:
[xmin, xmax, ymin, ymax] = [-15, 15, -15, 9]

# 1st way to set axes limits:
# extent = [xmin, xmax, ymin, ymax]
# ax.set_extent(extent, crs=ccrs.PlateCarree())


#plt.set_cmap(cmap=plt.get_cmap('nipy_spectral'))
plt.set_cmap(cmap=plt.get_cmap('turbo'))
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, alpha=0.5, linestyle='--')
gl.top_labels = False
gl.ylabels_right = False
#gl.xlocator = matplotlib.ticker.MaxNLocator(10)
#gl.xlocator = matplotlib.ticker.AutoLocator
# gl.xlocator = matplotlib.ticker.FixedLocator(np.arange(0, 360 ,30))

levels = 10
cs = ax.contourf(ds.lon,ds.lat,np.squeeze(sst), levels, extend='both', transform=ccrs.PlateCarree())
# cs = ax.pcolormesh(ds.longitude,ds.latitude,np.squeeze(ds.sla), vmin=levels[0], vmax=levels[-1], transform=ccrs.PlateCarree())
# cb = plt.colorbar(cs,ax=ax,shrink=.8,pad=.05)
cb = plt.colorbar(cs,fraction = 0.022,extend='both')
cb.set_label('SLA [m]',fontsize = 10)
ax.coastlines()
ax.add_feature(cartopy.feature.LAND, zorder=3, facecolor=[.6,.6,.6], edgecolor='black')

# 2nd way to set axes limits:
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)

#plot_ops_area(ax,transform=ccrs.PlateCarree(),color='w')

# Add a 10 km scale bar
#km_per_deg_lat=gsw.geostrophy.distance((125,125), (37,38))/1000
#deg_lat_equal_10km=10/km_per_deg_lat
#ax.plot(-123.75+np.asarray([0, 0]),36.75+np.asarray([0.,deg_lat_equal_10km]),transform=ccrs.PlateCarree())

if savefig:                               #creating a directory for the image
    plt.savefig(__figdir__+'SLA.'+plotfiletype,**savefig_args)
# Out:
# C:\Users\jtomf\anaconda3\envs\base2\lib\site-packages\cartopy\mpl\gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# <ipython-input-15-ffda7efa0aee>:26: MatplotlibDeprecationWarning: The 'extend' parameter to Colorbar has no effect because it is overridden by the mappable; it is deprecated since 3.3 and will be removed two minor releases later.
#   cb = plt.colorbar(cs,fraction = 0.022,extend='both')

# %%
__figdir__+'SLA.'+plotfiletype+'ocean'
# Out:
# '../plots/SMODE_SLA.pngocean'

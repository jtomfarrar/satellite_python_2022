# %% [markdown]
# # SST Plots/create movie using ffmpeg

# %%
import numpy as np
import xarray as xr
from matplotlib import pyplot as plt
import pandas as pd
from glob import glob
from dateutil import parser
import cartopy.crs as ccrs      
import cartopy #import projections
import gsw
import cftime
import datetime

# %%
path='/Users/lfp/Desktop/SST_amsr2/2016/*.nc'

# %%
fnames = glob(path)
fnames.sort()
#ds = xr.open_mfdataset(path,concat_dim='time',combine='nested')
for fname in fnames:
    print(parser.parse(fname.split('/')[-1].split('_')[-2]))
# Out:
# 2016-01-02 00:00:00
# 2016-01-09 00:00:00
# 2016-01-16 00:00:00
# 2016-01-23 00:00:00
# 2016-01-30 00:00:00
# 2016-02-06 00:00:00
# 2016-02-13 00:00:00
# 2016-02-20 00:00:00
# 2016-02-27 00:00:00
# 2016-03-05 00:00:00
# 2016-03-12 00:00:00
# 2016-03-19 00:00:00
# 2016-03-26 00:00:00
# 2016-04-02 00:00:00
# 2016-04-09 00:00:00
# 2016-04-16 00:00:00
# 2016-04-23 00:00:00
# 2016-04-30 00:00:00
# 2016-05-07 00:00:00
# 2016-05-14 00:00:00
# 2016-05-21 00:00:00
# 2016-05-28 00:00:00
# 2016-06-04 00:00:00
# 2016-06-11 00:00:00
# 2016-06-18 00:00:00
# 2016-06-25 00:00:00
# 2016-07-02 00:00:00
# 2016-07-09 00:00:00
# 2016-07-16 00:00:00
# 2016-07-23 00:00:00
# 2016-07-30 00:00:00
# 2016-08-06 00:00:00
# 2016-08-13 00:00:00
# 2016-08-20 00:00:00
# 2016-08-27 00:00:00
# 2016-09-03 00:00:00
# 2016-09-10 00:00:00
# 2016-09-17 00:00:00
# 2016-09-24 00:00:00
# 2016-10-01 00:00:00
# 2016-10-08 00:00:00
# 2016-10-15 00:00:00
# 2016-10-22 00:00:00
# 2016-10-29 00:00:00
# 2016-11-05 00:00:00
# ...

# %%
ds = xr.open_mfdataset(fnames,concat_dim='time',combine='nested')
ds
# Out:
# <xarray.Dataset>
# Dimensions:             (lon: 1440, lat: 720, time: 46)
# Coordinates:
#   * lon                 (lon) float32 0.125 0.375 0.625 ... 359.4 359.6 359.9
#   * lat                 (lat) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
# Dimensions without coordinates: time
# Data variables:
#     SST                 (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     wind_speed_LF       (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     wind_speed_MF       (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     wind_speed_AW       (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     water_vapor         (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     cloud_liquid_water  (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
# ...

# %%
ds = ds.assign_coords(time = [parser.parse(fname.split('/')[-1].split('_')[-2]) for fname in fnames])
ds
# Out:
# <xarray.Dataset>
# Dimensions:             (lon: 1440, lat: 720, time: 46)
# Coordinates:
#   * lon                 (lon) float32 0.125 0.375 0.625 ... 359.4 359.6 359.9
#   * lat                 (lat) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * time                (time) datetime64[ns] 2016-01-02 ... 2016-11-12
# Data variables:
#     SST                 (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     wind_speed_LF       (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     wind_speed_MF       (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     wind_speed_AW       (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     water_vapor         (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     cloud_liquid_water  (time, lat, lon) float32 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
# ...

# %%
#%matplotlib inline
# %matplotlib qt5

plt.rcParams['figure.figsize'] = (5,4)
plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 400
plt.close('all')

__figdir__ = '/Users/lfp/Desktop/File1/'
savefig_args = {'bbox_inches':'tight', 'pad_inches':0.2}
plotfiletype='png'

# To save the plotted image
savefig = 1

# %%
ds = ds.sel(lon=slice(80,100),lat=slice(5,25))

# %%
ds_1 = ds.sel(lat=slice(19,21),lon=slice(89,91))
ds_2=ds_1.mean(dim='lon')
ds_2 = ds_2.mean(dim='lat')
ds_2.SST.plot()

# %%
ds_3 = ds.sel(lat=slice(14,16),lon=slice(89,91))
ds_3=ds_3.mean(dim='lon')
ds_3 = ds_3.mean(dim='lat')
ds_3.SST.plot()

# %%
ds_4 = ds.sel(lat=slice(9,11),lon=slice(89,91))
ds_4=ds_4.mean(dim='lon')
ds_4 = ds_4.mean(dim='lat')
ds_4.SST.plot()

# %%
# Out:
# No handles with labels found to put in legend.

# %%
for i in range(len(ds.time)):
    
    plt.close('all')

    ax = plt.axes(projection = ccrs.PlateCarree(central_longitude=200))  # Orthographic
        #day_str=ds.time.dt.strftime("%b %d %Y").values[i]
    ax.set_title(f'BoB SST {str(ds.isel(time=i).time)[-10:]}')
        #ax.set_title(f'BoB SST '+day_str)


    plt.set_cmap(cmap=plt.get_cmap('nipy_spectral'))
    plt.set_cmap(cmap=plt.get_cmap('turbo'))

    gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, alpha=0.5, linestyle='--')
    gl.top_labels = False
    gl.ylabels_right = False

    levels = 10

    cs = ax.pcolormesh(ds.lon,ds.lat,np.squeeze(ds.isel(time=i).SST), vmin=25,vmax=32, transform=ccrs.PlateCarree())
    #ax.pcolormesh(ds.lon,ds.lat,np.squeeze(ds.SST), vmin=25,vmax=32, transform=ccrs.PlateCarree())

    cb = plt.colorbar(cs,fraction = 0.022, extend='both') 
    cb.set_label('SST [C]',fontsize = 10)
    ax.coastlines()
    ax.add_feature(cartopy.feature.LAND, zorder=3, facecolor=[.6,.6,.6], edgecolor='black')

       

    plt.savefig(__figdir__+f'SST{i:03d}'+'.'+plotfiletype,**savefig_args)
    plt.clf()
# Out:
# /Users/lfp/opt/anaconda3/lib/python3.9/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
# !ffmpeg -framerate 2 -i $__figdir__/SST%03d.png -s 1920x1080 $__figdir__/videosst2016.avi -y #make a video using ffmpeg
# Out:
# ffmpeg version N-105691-gc439c6b191-tessus  https://evermeet.cx/ffmpeg/  Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 11.0.0 (clang-1100.0.33.17)
# ...

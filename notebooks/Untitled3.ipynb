# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

# %%
# %matplotlib inline  
#%matplotlib qt5 
plt.rcParams['figure.figsize'] = (5,4)
plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 400
plt.close('all')

# %%
#Access file from the cloud
for i in range(8,9):
    if i<10:
        url="https://oceandata.sci.gsfc.nasa.gov/cgi/getfile/AQUA_MODIS.2019070"+str(i)+".L3m.DAY.NSST.x_sst.nc"
    else:
        url="https://oceandata.sci.gsfc.nasa.gov/cgi/getfile/AQUA_MODIS.201907"+str(i)+".L3m.DAY.NSST.x_sst.nc"

# %%
#Access files from a folder
directory='/Users/lfp/Downloads/requested/AQUA_MODIS.201907'
for i in range(8,9):
    if i<10:
        ds=xr.open_dataset(directory+'0'+str(i)+'.L3m.DAY.NSST.x_sst.nc')
        
    else:
        ds=xr.open_dataset(dir+str(i)+'.L3m.DAY.NSST.x_sst.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1394         try:
# -> 1395             variable = self._variables[name]
#    1396         except KeyError:
#
# KeyError: 'time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/x9/37hmb2cj4j72s26nwv19n_xh0000gn/T/ipykernel_3972/3797838563.py in <module>
#       4     if i<10:
#       5         ds=xr.open_dataset(directory+'0'+str(i)+'.L3m.DAY.NSST.x_sst.nc')
# ----> 6         ds = ds.sortby('time')
#       7     else:
#       8         ds=xr.open_dataset(dir+str(i)+'.L3m.DAY.NSST.x_sst.nc')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xarray/core/dataset.py in sortby(self, variables, ascending)
# ...

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 480, lon: 480, rgb: 3, eightbitcolor: 256)
# Coordinates:
#   * lat       (lat) float32 24.98 24.94 24.9 24.85 ... 5.146 5.104 5.062 5.021
#   * lon       (lon) float32 80.02 80.06 80.1 80.15 ... 99.85 99.9 99.94 99.98
# Dimensions without coordinates: rgb, eightbitcolor
# Data variables:
#     sst       (lat, lon) float32 ...
#     qual_sst  (lat, lon) float32 ...
#     palette   (rgb, eightbitcolor) uint8 ...
# Attributes: (12/60)
#     product_name:                     AQUA_MODIS.20190708.L3m.DAY.NSST.x_sst.nc
#     instrument:                       MODIS
#     title:                            MODISA Level-3 Equidistant Cylindrical ...
#     project:                          Ocean Biology Processing Group (NASA/GS...
#     platform:                         Aqua
#     temporal_range:                   day
#     ...                               ...
#     processing_level:                 L3 Mapped
#     cdm_data_type:                    grid
# ...

# %%
ds.isel(time=11).sst.plot(robust=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/x9/37hmb2cj4j72s26nwv19n_xh0000gn/T/ipykernel_3972/1721869740.py in <module>
# ----> 1 ds.isel(time=11).sst.plot(robust=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xarray/core/dataset.py in isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2357         # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    2358         # lists, or zero or one-dimensional np.ndarray's
# -> 2359         indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    2360
#    2361         variables = {}
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xarray/core/utils.py in drop_dims_from_indexers(indexers, dims, missing_dims)
#     833         invalid = indexers.keys() - set(dims)
#     834         if invalid:
# --> 835             raise ValueError(
# ...
